# %%
import unittest

from my_sum import sum

class TestSum(unittest.TestCase):
    def test_list_int(self):
        """
        Test that it can sum a list of integers
        """

        data = [1, 2, 3]
        result = sum(data)
        self.assertEqual(result, 6)

    def test_list_fraction(self):
        """
        Test that it can sum a list of fractions
        """
        data = [Fraction(1,4), Fraction(1, 4), Fraction(2, 5)]
        result = sum(data)
        self.assertEqual(result, 1)
        
if __name__ == "__main__":
    unittest.main()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import unittest
# ----> 3 from my_sum import sum
#       5 class TestSum(unittest.TestCase):
#       6     def test_list_int(self):
#
# ModuleNotFoundError: No module named 'my_sum'

# %%
#__init__
def sum(arg):
    total = 0
    for val in arg:
        total += val
    return total

# %%
#Summary after test# 
#These methods of testing code to verify that they work in sections is very important as it allows for a programmer to see which exact area the issue may be at. Being able to split classes and test them one by one allows for a quick and easy system to decect errors in the code being made.
