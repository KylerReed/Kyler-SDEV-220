# %%
#Import Pandas
import pandas as pd
import os

file_path = '/path/to/your/file/telco_churn.csv'
df = pd.read_csv(telco_churn.csv)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3 import os
#       5 file_path = '/path/to/your/file/telco_churn.csv'
# ----> 6 df = pd.read_csv(telco_churn.csv)
#       7 df.head()
#
# NameError: name 'telco_churn' is not defined

# %%
#Dataset Commands

df.head() #This shows first 5 rows
df.tail() #This shows last 5 rows
df.info() #This shows summary of rows and columns 
df.describe() #This shows stats for number columns

# %%
#Columns

df["ColumnName"]
df[["Col 1", "Col 2"]]

# %%
#Rows 

df.iloc[0]
df.iloc[0:10]

df.iloc[3]

# %%
#Filtering Data

df_filtered = df[df["ColumnName"] > 100]

# %%
#Adding and Removing Columns

#Add
df["NewColumn"] = df["col1"] + df["col2"]

#Remove

df = df.drop(columns=["UnneededColumn"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 #Adding and Removing Columns
#       2
#       3 #Add
# ----> 4 df["NewColumn"] = df["col1"] + df["col2"]
#       6 #Remove
#
# NameError: name 'df' is not defined

# %%
#Handling missing data 

df.isna().sum()

df = df.fillna(0)
df = df.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #Handling missing data
# ----> 3 df.isna().sum()
#       5 df = df.fillna(0)
#       6 df = df.dropna()
#
# NameError: name 'df' is not defined
